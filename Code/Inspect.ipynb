# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob

# %%
datadir = '../../BigData/kaggle-right-whale/right_whale_hunt/imgs/'

# %%
df = pd.read_csv(datadir + 'whale_00195/posteriorpdf_rebin16_64walkers_w_2753.csv')

# %%
plt.plot(df['lnprob'].max() - df['lnprob'], ',')
plt.xlabel('time [iteration number]')
plt.ylabel('max(lnprob) - lnprob')
plt.semilogy()
# Out:
# []

# %%
plt.plot(df['lnprob'].max() - df['lnprob'], df['rotation_angle'], ',')
plt.semilogx()
plt.xlabel('max(lnprob) - lnprob')
plt.ylabel('Whale heading [degrees CCW from East]')
#plt.axis([1,1e6,62,68])

# %%
25000/60./24
# Out:
# 17.36111111111111

# %%
whaledirs = glob(datadir + 'whale_*')

# %%
counter = 0
for whaledir in whaledirs:
    if whaledir[-5:] == '10977':
        print(counter, whaledir)
    counter += 1
# Out:
# (48, '../../../BigData/kaggle-right-whale/right_whale_hunt/imgs/whale_10977')
